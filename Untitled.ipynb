# %% [markdown]
# *-----ANÁLISE DE DADOS DO COVID-19-----*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *-----IMPORTANDO O ARQUIVO CSV-----*

# %%
df = pd.read_csv('/home/lucas/Downloads/HIST_PAINEL_COVIDBR_2020_Parte1_25nov2021.csv', sep=';')
df
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 714476  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714477  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714478  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714479  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714480  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [raw]
# -----DADOS DO 30º DIA

# %%
df[df.index == 30]
# Out:
#     regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 30  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#           data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 30  2020-03-26         13       210147125.0            2915         482
#
#     obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 30               77           20               NaN                    NaN
#
#     interior/metropolitana
# 30                     NaN

# %% [markdown]
# *-----MAIORES NÚMEROS DE CASOS NOVOS JÁ REGISTRADOS NO CE-----*

# %%
df[df.estado == "CE"].casosNovos.value_counts().head(6)
# Out:
# 0    12030
# 1     2692
# 2     1344
# 3      866
# 4      686
# 5      522
# Name: casosNovos, dtype: int64

# %% [markdown]
# *-----DIAS NO CEARÁ COM ÓBITOS ACIMA DE 100 PESSOAS-----*

# %%
df[df.estado == "CE"][df.obitosNovos > 100]
# Out:
# /tmp/ipykernel_15916/2852321447.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.estado == "CE"][df.obitosNovos > 100]                                 #Dias no ceará que os óbitos foram acima de 100
#           regiao estado  municipio  coduf    codmun  codRegiaoSaude  \
# 1647    Nordeste     CE        NaN     23       NaN             NaN
# 1658    Nordeste     CE        NaN     23       NaN             NaN
# 1661    Nordeste     CE        NaN     23       NaN             NaN
# 1663    Nordeste     CE        NaN     23       NaN             NaN
# 1664    Nordeste     CE        NaN     23       NaN             NaN
# 1666    Nordeste     CE        NaN     23       NaN             NaN
# 1670    Nordeste     CE        NaN     23       NaN             NaN
# 1671    Nordeste     CE        NaN     23       NaN             NaN
# 1674    Nordeste     CE        NaN     23       NaN             NaN
# ...

# %% [markdown]
# *-----FILTRAR APENAS POR DADOS GERAIS DO PAÍS-----*

# %%
df[df.estado.isna()]
# Out:
#      regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4    Brasil    NaN       NaN     76     NaN             NaN             NaN
# ..      ...    ...       ...    ...     ...             ...             ...
# 153  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 154  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 155  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 156  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 157  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
# ...

# %% [markdown]
# *-----CRIAÇÃO DA TABELA DE ÓBITOS TOTAIS-----*

# %%
df['obitosTotais'] = df['obitosAcumulado'] + df['obitosNovos']                  
df.tail()
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 714476  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714477  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714478  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714479  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 714480  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 714476  DISTRITO FEDERAL  2020-07-27         31         3015268.0
# 714477  DISTRITO FEDERAL  2020-07-28         31         3015268.0
# 714478  DISTRITO FEDERAL  2020-07-29         31         3015268.0
# 714479  DISTRITO FEDERAL  2020-07-30         31         3015268.0
# 714480  DISTRITO FEDERAL  2020-07-31         31         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 714476           98480        2148             1339           31
# ...

# %% [markdown]
# *-----MÁXIMO DE ÓBITOS REGISTRADOS NOS ESTADOS-----*

# %%
agrupa_estado = df.groupby('estado')
a = agrupa_estado.obitosNovos.max().sort_values()
a
# Out:
# estado
# TO     15
# AC     16
# AP     18
# MS     20
# RO     31
# PI     36
# SE     39
# AL     39
# RR     40
# PB     46
# DF     52
# SC     59
# ES     63
# RN     70
# PR     71
# BA     72
# RS     75
# MA     77
# GO     92
# MG     95
# AM    102
# PE    140
# PA    224
# MT    245
# CE    261
# RJ    324
# SP    713
# Name: obitosNovos, dtype: int64

# %% [markdown]
# *-----MÁXIMO DE CASOS NOVOS REGISTRADOS EM APENAS UM DIA-----*

# %%
df.casosNovos.max()            #Vai retornar 69074                                                          
df[df.casosNovos == 69074]
# Out:
#      regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 155  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#            data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 155  2020-07-29         31       210147125.0         2552265       69074
#
#      obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# 155            90134         1595         1786753.0               675378.0
#
#      interior/metropolitana  obitosTotais
# 155                     NaN         91729

# %% [markdown]
# *-----MÉDIA DE CASOS NOVOS NOS ÚLTIMOS 100 DIAS-----*

# %%
ultimos_50_dias = df.tail(100)                                                      
ultimos_50_dias.casosNovos.mean()
# Out:
# 1053.46

# %% [markdown]
# *----- VARIAÇÃO DE CASOS NOVOS NO BRASIL -----*

# %%
ax = casos_novos_BR = df[df.estado.isna()].casosNovos.plot(
figsize=(13,6),xlabel="Dias",ylabel="nº de casos",title="Casos de covid no Brasil")                           
casos_novos_BR
# Out:
# <AxesSubplot:title={'center':'Casos de covid no Brasil'}, xlabel='Dias', ylabel='nº de casos'>

# %% [markdown]
# *-----VARIAÇÃO DE CASOS ACUMULADOS NO BRASIL-----*

# %%
casos_acumulados_BR = df[df.estado.isna()].casosAcumulado.plot(xlabel="Dias",ylabel="nº de casos",figsize=(13,6))                  
casos_acumulados_BR
# Out:
# <AxesSubplot:xlabel='Dias', ylabel='nº de casos'>

# %% [markdown]
# *-----ÓBITOS NOVOS NO BRASIL-----*

# %%
casos_acumulados_BR = df[df.estado.isna()].obitosNovos.plot(xlabel="Dias",ylabel="nº de casos",figsize=(13,6))                  
casos_acumulados_BR
# Out:
# <AxesSubplot:xlabel='Dias', ylabel='nº de casos'>

# %% [markdown]
# *-----ÓBITOS ACUMULADOS NO BRASIL-----*

# %%
casos_acumulados_BR = df[df.estado.isna()].obitosAcumulado.plot(xlabel="Dias",ylabel="nº de casos")                  
casos_acumulados_BR
# Out:
# <AxesSubplot:xlabel='Dias', ylabel='nº de casos'>

# %% [markdown]
# *-----COMPARAÇÃO ENTRE CASOS E OBITOS-----*

# %%
df = pd.concat([df.casosAcumulado.tail(100),df.casosNovos.tail(100),df.obitosAcumulado.tail(100),df.obitosNovos.tail(100)],axis =1)
df.plot(figsize=(13,6),title=(""),ylabel="nº de casos")
# Out:
# <AxesSubplot:xlabel='Dias', ylabel='nº de casos'>

# %% [markdown]
# *-----COMPARAÇÃO ENTRE NOVOS CASOS E ÓBITOS (SEM OS CASOS ACUMULADOS)-----*

# %%
df = pd.concat([df.casosNovos.tail(100),df.obitosAcumulado.tail(100),df.obitosNovos.tail(100)],axis =1)
df.plot(figsize=(13,6),title=(""),xlabel="Dias",ylabel="nº de casos")
# Out:
# <AxesSubplot:xlabel='Dias', ylabel='nº de casos'>

# %% [markdown]
# *-----VARIAÇÃO DE CASOS NOVOS NO CEARÁ-----*

# %%
df[df.estado == "CE"].tail(1500).casosNovos.plot(figsize=(13,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# *-----SOMA TOTAL DE ÓBITOS NO CEARÁ-----*

# %%
df[df.estado == "CE"].obitosNovos.sum()
# Out:
# 15336

# %% [markdown]
# *-----VARIAÇÃO DE CASOS NOVOS EM FORTALEZA------*

# %%
casos_em_fortaleza = df[df.municipio == "Fortaleza"].casosNovos.plot(figsize=(13,6))

# %% [markdown]
# *-----VARIAÇÃO DE CASOS NOVOS EM SALVADOR-----*

# %%
casos_em_salv = df[df.municipio == "Salvador"].casosNovos.plot(figsize=(13,6))

# %% [markdown]
# *-----VARIAÇÃO DE CASOS NOVOS EM TERESINA-----*

# %%
casos_em_nat = df[df.municipio == "Teresina"].casosNovos.plot(figsize=(13,6))

# %% [markdown]
# *-----VARIAÇÃO DE CASOS EM FORTALEZA-----*

# %%
import matplotlib.pyplot as plt

y = df[df.municipio == "Fortaleza"].casosNovos
x = df[df.municipio == "Fortaleza"].index                                           


plt.figure(figsize=(20,10))

plt.bar(x,y)
# Out:
# <BarContainer object of 127 artists>

# %% [markdown]
# *-----COMPRAÇÃO ÓBITOS X CASOS NOVOS-----*

# %%
estados = ['CE','PI','RN','PB']
casos_novos = [df[df.estado == "CE"].casosNovos.sum(),df[df.estado == "PI"].casosNovos.sum(),df[df.estado == "RN"].casosNovos.sum(),df[df.estado == "PB"].casosNovos.sum()]
obitos_novos = [df[df.estado == "CE"].obitosNovos.sum(),df[df.estado == "PI"].obitosNovos.sum(),df[df.estado == "RN"].obitosNovos.sum(),df[df.estado == "PB"].obitosNovos.sum()]

ypos = np.arange(len(estados))                                                

for i in range(len(estados)):
  plt.text(i,casos_novos[i],casos_novos[i],ha="center",va="bottom")
  plt.text(i,obitos_novos[i],obitos_novos[i],ha="center",va="bottom")


plt.title("Casos novos de covid nos estados do Nordeste")
plt.ylabel("Nº de Casos")
plt.xticks(ypos,estados)
plt.bar(ypos,casos_novos, label="Novos Casos")
plt.bar(ypos,obitos_novos, label="Novos óbitos")
plt.legend()

# %% [markdown]
# *-----SOMATÓRIO TOTAL DE CASOS NOS ESTADOS DO NORDESTE-----*

# %%
estados = ['CE','PI','RN','PB']
casos_novos = [df[df.estado == "CE"].casosNovos.sum(),df[df.estado == "PI"].casosNovos.sum(),df[df.estado == "RN"].casosNovos.sum(),df[df.estado == "PB"].casosNovos.sum()]

ypos = np.arange(len(estados))                                                

for i in range(len(estados)):
  plt.text(i,casos_novos[i],casos_novos[i],ha="center",va="bottom")



plt.legend()
plt.title("Casos novos de covid nos estados do Nordeste")
plt.ylabel("Nº de Casos")
plt.xticks(ypos,estados)
plt.bar(ypos,casos_novos)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <BarContainer object of 4 artists>

# %% [markdown]
# *-----COMPARAÇÃO ENTRE NÚMERO DE ÓBITOS E NOVOS CASOS EM FORTALEZA-----*

# %%
y1 = df[df.municipio == "Fortaleza"].casosNovos
x1 = df[df.municipio == "Fortaleza"].data

y2 = df[df.municipio == "Fortaleza"].obitosNovos
x2 = df[df.municipio == "Fortaleza"].data

plt.figure(figsize=(30,15))
plt.xlabel="Dias"
plt.ylabel="nº de casos"
plt.plot (x1,y1, '+--m')
plt.plot (x2,y2 ,'o:k')

# %% [markdown]
# *-----COMPARAÇÃO ENTRE NÚMERO DE ÓBITOS E NOVOS CASOS EM FORTALEZA-----*

# %%
def autolabel(grupos):
  for i in grupos:
    h = i.get_height()
    ax.annotate('{}'.format(h),
                xy = (i.get_x()+i.get_width() /2,h),
                xytext = (0,3),
                textcoords = 'offset points',
                ha = 'center')

data = df[df.municipio == "Fortaleza"].data

obitos = df[df.municipio == "Fortaleza"].obitosNovos
novos_casos = df[df.municipio == "Fortaleza"].casosNovos
x = np.arange(len(data))
largura = 0.20
fig,ax = plt.subplots(figsize = (20,10)) 
grupo1 = ax.bar(x -largura/2,obitos,largura,label = "Óbitos")
grupo2 = ax.bar(x +largura/2,novos_casos,largura,label = "Novos Casos")
ax.legend()   
ax.set_title('Comparação entre número de óbitos e novos casos', fontsize = 25) 
ax.set_xticklabels(data, fontsize = 15) 

autolabel(grupo1)                                                                    #Define o número que aparece em cima da barra
autolabel(grupo2)                                                                    #Define o número que aparece em cima da barra

plt.show()
# Out:
# /tmp/ipykernel_28269/365289443.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(data, fontsize = 15)

# %% [markdown]
# *-----PORCENTAGEM DE MORTOS EM RELAÇÃO À POPULAÇÃO-----*

# %%
def porcentagem(a):
    print("A porcentagem de mortes em relação à população total do estado",a,
          "é: " "%",df[df.estado == a].obitosNovos.sum()/df[df.estado == a].populacaoTCU2019.max() * 100)

# %%
porcentagem("CE")
porcentagem("BA")
porcentagem("RN")
porcentagem("PB")
porcentagem("PI")
porcentagem("AL")
porcentagem("MA")
porcentagem("SE")
# Out:
# A porcentagem de mortes em relação à população total do estado CE é: % 0.16793549069554597
# A porcentagem de mortes em relação à população total do estado BA é: % 0.04656740534431909
# A porcentagem de mortes em relação à população total do estado RN é: % 0.10134442475917868
# A porcentagem de mortes em relação à população total do estado PB é: % 0.0901415012517026
# A porcentagem de mortes em relação à população total do estado PI é: % 0.08120426722619604
# A porcentagem de mortes em relação à população total do estado AL é: % 0.09390664528847228
# A porcentagem de mortes em relação à população total do estado MA é: % 0.0851709659441928
# A porcentagem de mortes em relação à população total do estado SE é: % 0.12476638929201599

# %% [markdown]
# * **-----Algumas perguntas que podem ser respondidas pós análise de dados-----** *

# %% [markdown]
# 1.Qual estado do Nordeste obteve a maior média percentual de mortes por habitante?
#
# R: O estado do Ceará apresentou a maior média percentual de mortes por habitante: %0.16 da população, equivalente a 15336 pessoas.

# %% [markdown]
# 2.Qual estado do Nordeste obteve a menor média percentual de mortes por habitante?
#
# R: O estado da Bahia apresentou a menor média percentual de mortes por habitante: %0.04 da população, equivalente a 6926 pessoas.

# %% [markdown]
# 3.Qual o período do maior número de mortes no Ceará?
#
# R: O apíce de mortes ocorreu entre os dias 5 de maio e 6 de junho, dias que registraram a maior quantidade de
# novos óbitos e mantiveram uma média alta.
#
# Foram registrados 261 novos óbitos em 5 de maio e 233 em 6 de junho, picos acima da média apresentada durante o período de observação

# %% [markdown]
# 4.O que os gráficos de óbitos e casos novos no Brasil tem a nos dizer?
#
# R: Os gráficos mostram que o Brasil ainda não alcançou o pico da pandemia e que os casos continuam a crescer de forma exponencial.
#
# Dessa forma, é seguro afirmar que o pico da pandemia ainda não foi alcançado e que graças ao aumento de casos acumulados a expectativa é um aumento no número de mortes.

# %% [markdown]
# 5.Qual a semelhança entre os gráficos de casos e obitos novos e acumulados?
#
# R: Todos eles aprensentam um gráfico em crescimento.
#
# Os gráficos de novos casos e óbitos apresentam pequenas baixas que são seguidas por um novo pico de altas, isso ocorre em partes graças ao número de casos acumulados, que crescem de forma exponencial,o que dificulta a contabilidade.

# %% [markdown]
# 6.Os picos de novos casos nos estados ocorreram em períodos semelhantes?
#
# R: Não, os picos de novos casos ocorreram em períodos distintos nos estados, não havendo correlação entre a
# data e o aumento ou diminuição no número de casos.
